# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/Data/housing/train (3).csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.isna().sum().reset_index()
# Out:
#             index    0
# 0              Id    0
# 1      MSSubClass    0
# 2        MSZoning    0
# 3     LotFrontage  259
# 4         LotArea    0
# ..            ...  ...
# 76         MoSold    0
# 77         YrSold    0
# 78       SaleType    0
# 79  SaleCondition    0
# 80      SalePrice    0
#
# [81 rows x 2 columns]

# %%
features = ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
X = df[features]

# %%
y = df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state =1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

y_pred = rf_model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))

rmse
# Out:
# 27509.244837066082

# %%
testfeatures = ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
test_data = pd.read_csv('/content/drive/MyDrive/Machine Learning/Data/housing/test.csv')


X_test_final = test_data[testfeatures]

predicted_sale_prices = rf_model.predict(X_test_final)


submission = pd.DataFrame({
    'Id': test_data['Id'],
    'SalePrice': predicted_sale_prices
})


submission.to_csv('/content/drive/MyDrive/Machine Learning/Data/housing/submission.csv', index=False)

# This line is just to confirm that the submission DataFrame has been created correctly
print(submission.head())
# Out:
#      Id  SalePrice
# 0  1461  121173.66
# 1  1462  151883.00
# 2  1463  173906.14
# 3  1464  183227.37
# 4  1465  194014.12

# %%
test_data.isna().sum() ==0
# Out:
# Id                True
# MSSubClass        True
# MSZoning         False
# LotFrontage      False
# LotArea           True
#                  ...
# MiscVal           True
# MoSold            True
# YrSold            True
# SaleType         False
# SaleCondition     True
# Length: 80, dtype: bool

# %%
features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
# Identify numerical columns with no missing values
numerical_cols = test_data.select_dtypes(include=['number']).columns
no_na_numerical_cols = [col for col in numerical_cols if test_data[col].isna().sum() == 0]

# Print the list of columns
print(no_na_numerical_cols)
# Out:
# ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
